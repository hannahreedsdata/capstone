# %% [markdown]
# "Random" Tracks EDA

# %% [markdown]
# ### Danceability

# %%
genres_ordered_by_danceability = list(genretracks_info_features.groupby('genre')['danceability']
                                      .median().sort_values(ascending=False).index)

plt.figure(figsize=(10,40))
sns.boxplot(x='danceability', y='genre', data=genretracks_info_features, order=genres_ordered_by_danceability);

plt.title('Danceability Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Energy

# %%
genres_ordered_by_energy = list(genretracks_info_features.groupby('genre')['energy']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='energy', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_energy,
            flierprops=flierprops);

plt.title('Energy Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Loudness

# %%
genres_ordered_by_loudness = list(genretracks_info_features.groupby('genre')['loudness']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='loudness', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_loudness,
            flierprops=flierprops);

plt.title('Loudnesss by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Speechiness

# %%
genres_ordered_by_speechiness = list(genretracks_info_features.groupby('genre')['speechiness']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='speechiness', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_speechiness,
            flierprops=flierprops);

plt.title('speechiness Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Instrumentalness

# %%
genres_ordered_by_instrumentalness = list(genretracks_info_features.groupby('genre')['instrumentalness']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='instrumentalness', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_instrumentalness,
            flierprops=flierprops);

plt.title('Instrumentalness Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Acousticness

# %%
genres_ordered_by_acousticness = list(genretracks_info_features.groupby('genre')['acousticness']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='acousticness', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_acousticness,
            flierprops=flierprops);

plt.title('Acousticness Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Liveness

# %%
genres_ordered_by_liveness = list(genretracks_info_features.groupby('genre')['liveness']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'

plt.figure(figsize=(10,35))
sns.boxplot(x='liveness', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_liveness,
            flierprops=flierprops);

plt.title('Liveness Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Valence

# %%
genres_ordered_by_valence = list(genretracks_info_features.groupby('genre')['valence'].median().sort_values(ascending=False).index)

plt.figure(figsize=(10,40))
sns.boxplot(x='valence', y='genre', data=genretracks_info_features, order=genres_ordered_by_valence);

plt.title('Valence Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Tempo

# %%
genres_ordered_by_tempo = list(genretracks_info_features.groupby('genre')['tempo'].median().sort_values(ascending=False).index)

plt.figure(figsize=(10,40))
sns.boxplot(x='tempo', y='genre', data=genretracks_info_features, order=genres_ordered_by_tempo);

plt.title('Tempo Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');

# %% [markdown]
# ### Duration

# %%
genres_ordered_by_duration = list(genretracks_info_features.groupby('genre')['duration_ms']
                                      .median().sort_values(ascending=False).index)

# from https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(marker='o', markersize=3)
# , markerfacecolor='darkgray', markeredgecolor='darkgray'
plt.set_ylim(2000000)

plt.figure(figsize=(10,35))
sns.boxplot(x='duration_ms', y='genre', 
            data=genretracks_info_features, 
            order=genres_ordered_by_duration,
            flierprops=flierprops);

# **{y_lim : 2000000}

plt.title('Duration Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-8cf9bf0e3d06> in <module>
#       5 flierprops = dict(marker='o', markersize=3)
#       6 # , markerfacecolor='darkgray', markeredgecolor='darkgray'
# ----> 7 plt.set_ylim(2000000)
#       8
#       9 plt.figure(figsize=(10,35))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_ylim'

# %% [markdown]
# ### Valence, limited list

# %%
genres_ordered_by_valence

['funk',
 'salsa',
 'disco',
 'ska',
 'samba',
 'groove',
 'afrobeat',
 'reggae',
 'pagode',
 'reggaeton',
 'spanish',
 'happy',
 'children',
 'kids',
 'dancehall',
 'pop-film',
 'latin',
 'latino',
 'soul',
 'road-trip',
 'bluegrass',
 'garage',
 'sertanejo',
 'honky-tonk',
 'blues',
 'chicago-house',
 'turkish',
 'summer',
 'indian',
 'world-music',
 'swedish',
 'j-idol',
 'power-pop',
 'german',
 'brazil',
 'british',
 'iranian',
 'bossanova',
 'punk-rock',
 'tango',
 'french',
 'anime',
 'work-out',
 'country',
 'j-dance',
 'mpb',
 'rock-n-roll',
 'breakbeat',
 'electro',
 'j-pop',
 'j-rock',
 'hard-rock',
 'indie-pop',
 'songwriter',
 'party',
 'guitar',
 'hip-hop',
 'k-pop',
 'alt-rock',
 'punk',
 'dance',
 'jazz',
 'psych-rock',
 'rock',
 'r-n-b',
 'indie',
 'alternative',
 'deep-house',
 'industrial',
 'pop',
 'synth-pop',
 'chill',
 'club',
 'electronic',
 'singer-songwriter',
 'trip-hop',
 'detroit-techno',
 'folk',
 'gospel',
 'hardcore',
 'holidays',
 'emo',
 'malay',
 'cantopop',
 'show-tunes',
 'romance',
 'new-release',
 'grunge',
 'minimal-techno',
 'techno',
 'rainy-day',
 'edm',
 'comedy',
 'acoustic',
 'house',
 'post-dubstep',
 'goth',
 'metal-misc',
 'disney',
 'mandopop',
 'trance',
 'movies',
 'drum-and-bass',
 'sad',
 'dubstep',
 'dub',
 'hardstyle',
 'idm',
 'philippines-opm',
 'sleep',
 'heavy-metal',
 'progressive-house',
 'metalcore',
 'study',
 'death-metal',
 'new-age',
 'opera',
 'piano',
 'grindcore',
 'soundtracks',
 'black-metal',
 'classical',
 'ambient']
# Out:
# ['funk',
#  'salsa',
#  'forro',
#  'rockabilly',
#  'disco',
#  'ska',
#  'samba',
#  'groove',
#  'afrobeat',
#  'reggae',
#  'pagode',
#  'reggaeton',
#  'spanish',
#  'happy',
#  'children',
#  'kids',
#  'dancehall',
#  'pop-film',
#  'latin',
#  'latino',
#  'soul',
#  'road-trip',
#  'bluegrass',
#  'garage',
#  'sertanejo',
#  'honky-tonk',
#  'blues',
#  'chicago-house',
#  'turkish',
#  'summer',
#  'indian',
#  'world-music',
#  'swedish',
#  'j-idol',
#  'power-pop',
#  'german',
#  'brazil',
#  'british',
#  'iranian',
#  'bossanova',
#  'punk-rock',
#  'tango',
#  'french',
#  'anime',
#  'work-out',
#  'country',
#  'j-dance',
#  'mpb',
#  'rock-n-roll',
#  'breakbeat',
#  'electro',
#  'j-pop',
#  'j-rock',
#  'hard-rock',
#  'indie-pop',
#  'songwriter',
#  'party',
#  'guitar',
#  'hip-hop',
#  'k-pop',
#  'alt-rock',
#  'punk',
#  'dance',
#  'jazz',
#  'psych-rock',
#  'rock',
#  'r-n-b',
#  'indie',
#  'alternative',
#  'deep-house',
#  'industrial',
#  'pop',
# ...

# %%
genres_ordered_by_valence = list(genretracks_info_features.groupby('genre')['valence'].median().sort_values(ascending=False).index)

plt.figure(figsize=(10,40))
sns.boxplot(x='valence', y='genre', data=genretracks_info_features, order=genres_ordered_by_valence);

plt.title('Valence Scores by Genre \n')

plt.xlabel('\n Score')
plt.ylabel('Genre \n ');
